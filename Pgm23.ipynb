# %%
print("HLO WORLD" );
# Out:
# HLO WORLD

# %%
print(f" Happy Birthday,  ")
# Out:
#  Happy Birthday,

# %%
temp1 =77
celsius=(temp1-32)*5/9
print(celsius)


temp2 =95
celsius=(temp2-32)*5/9
print(celsius)


temp3 =90
celsius=(temp3-32)*5/9
print(celsius)
# Out:
# 25.0
# 35.0
# 32.22222222222222

# %%
def fahrenhiet_to_celsius(fahrenheit):
    celsius=(fahrenheit-32)*5/9

print(fahrenhiet_to_celsius(77))
print(fahrenhiet_to_celsius(95))
print(fahrenhiet_to_celsius(90))
# Out:
# None
# None
# None

# %%
def number_of_crops():
  return 150
number_of_crops()
# Out:
# 150

# %%
def weather_report_update():
  print("the weather is hot today with no rain")
weather_report_update()
# Out:
# the weather is hot today with no rain

# %%
def agriculture_backbone_of_india ():
  print("jai jawaan jai kisan")
agriculture_backbone_of_india()
# Out:
# jai jawaan jai kisan

# %%
def plant_info(plant_name):
     print(f"the {plant_name},requires at least 8 hours of sunlight per day" )
plant_info("snake tree")
# Out:
# the snake tree,requires at least 8 hours of sunlight per day

# %%
def water_needs(plant_type):
    if plant_type=="rice":
      return 30
    elif  plant_type=="wheat":
     return 20
    else:
     return 25
water_needs("rice")
# Out:
# 30

# %%
def irrigation_needs(moisture_level,rainfall):
     if moisture_level<40 and rainfall<10:
      print("irrigation needed")
     else:
      print("no irrigation needed")
# Out:
# no irrigation needed

# %%
def total_yield(area,yield_per_hectares):
  return area*yield_per_hectares
total_yield(100,2)
# Out:
# 200

# %%
def total_yield():
 area=int(input("enter the area"))
 yield_per_hectares=float(input("enter the yield per hectares"))
 calculated_yield= area*yield_per_hectares
 return  calculated_yield
y=total_yield()
print(y)
print("hi there")
# Out:
# enter the area30
# enter the yield per hectares30
# 900.0
# hi there

# %%
def is_ready_for_harvest(day_since_planted, plant_type):
    if day_since_planted >= 120 and plant_type == "corn":
        return True
    else:
        return False

plant_type_input = input("enter the plant type: ")
days_since_planted_input = int(input("enter the days since planted: "))
result = is_ready_for_harvest(days_since_planted_input, plant_type_input)
print(result)
# Out:
# enter the plant type: 20
# enter the days since planted: 25
# False

# %%
def weather_condition():
 temperature=28
 humidity=70
 return temperature,humidity

temp,humidity=weather_condition()
print(f"temperture:{temp},humidity:{humidity}")
# Out:
# temperture:28,humidity:70
