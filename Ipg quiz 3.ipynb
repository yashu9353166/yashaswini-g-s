# %%
a=[1,2,3,4,]
b=a
c=a.copy()
d=a
a[0]=[5]
print(a,b,c,d)
# Out:
# [[5], 2, 3, 4] [[5], 2, 3, 4] [1, 2, 3, 4] [[5], 2, 3, 4]

# %%
count=0
while count<3:
  print("hello")
  count +=1
else:
  print("else block")
# Out:
# hello
# hello
# hello
# else block

# %%
a=["physics","chemistry",1997,2000]
print(a[1][-1])
# Out:
# y

# %%
li=["harsh","pratik","bob","dhruv"]
print(li[1][-1])
# Out:
# k

# %%
a=[]
a.append([1,[2,3],4])
a.extend([7,8,9])
print(a[0][1][1]+a[2])
# Out:
# 11

# %%
def REVERSE(a):
  a.reverse()
  return(a)

def ysolf(a):
  b=[]
  b.extend(REVERSE(a))
  print(b)
a=[1,3.1,5.31,7.531]
ysolf(a)
# Out:
# [7.531, 5.31, 3.1, 1]

# %%
a=[1,2,3,4,5]
b=a
b[0]=0;
print(a)
# Out:
# [0, 2, 3, 4, 5]

# %%
a=[1,2,3,4,5]
b=a
b=[0];            #no effect
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
i=1
while True:
  if i%7==0:
     break
  print(i,end=" ")
  i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2403515588.py in <cell line: 0>()
#       1 i=1
# ----> 2 while True:
#       3   if i%7==0:
#       4     break
#       5     print(i,end=" ")
#
# KeyboardInterrupt:

# %%
a=["Greeks","For","Greeks"]
b=[i[0].upper()for i in a ]
print(b)
# Out:
# ['G', 'F', 'G']

# %%
li=["a","b","c","d","e"]
print(li[10:])
# Out:
# []

# %%
for num in range(10,14):
  for i in range(2,num):
    if num %i==1:
        print(num)
        break
# Out:
# 10
# 11
# 12
# 13

# %%
li =range(100,110)
print(li.index(105))
# Out:
# 5

# %%
x="abcd"
for i in range(len(x)):
  print(i,end=" ")
# Out:
# 0 1 2 3

# %%
x="abcd"
for i, char in enumerate(x):
  print(i,char)
# Out:
# 0 a
# 1 b
# 2 c
# 3 d

# %%
x="abcd"
for i, char in enumerate(x):
  print(f"Index {i} is character {x[i]}")
# Out:
# Index 0 is character a
# Index 1 is character b
# Index 2 is character c
# Index 3 is character d

# %%
li=[1,1.33,'GFG',0,'no','none','g',True]
val1,val2=0,''
for x in li:
  if (type(x)==int or type(x)==float):
    val1+=x
  elif type(x)==str:
    val2+=x
  else:
    break
print(val1,val2)
# Out:
# 2.33 GFGnononeg

# %%
def addTolist(a):
  a+=[10]
b=[10,20,30,40]
addTolist(b)
print(len(b))
# Out:
# 5

# %%
li=[1,2,3,4,5,6,7,8,9]
print(li.pop(-3),end=' ')
print(li.pop(0),end=' ')
print(li.pop(1),end='')
# Out:
# 7 1 3
